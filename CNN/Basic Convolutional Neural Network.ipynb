# %% [markdown]
# # Basic Convolutional Neural Network

# %% [markdown]
# ## Part 1 - Building the Convolutional Neural Network

# %% [markdown]
# Importing the libraries

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# /home/bhanuka/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Initialize the classfier

# %%
classifier = Sequential()

# %% [markdown]
# Adding the convolutional layer

# %%
classifier.add(Convolution2D(32,(3,3),input_shape=(64,64,3), activation='relu'))

# %% [markdown]
# Adding the pooling layer

# %%
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# Adding the flattening layer

# %%
classifier.add(Flatten())

# %% [markdown]
# Adding the Full Connection

# %%
classifier.add(Dense(units=128,activation='relu'))
classifier.add(Dense(units=1,activation='sigmoid'))

# %% [markdown]
# Compiling the CNN

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Getting the progress onto Tensorboard

# %%
from keras.callbacks import TensorBoard
from time import time
tensorboard = TensorBoard(log_dir="logs/{}".format(time()))

# %% [markdown]
# Fit the CNN to the images

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_set = train_datagen.flow_from_directory(
        'dataset/training_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

test_set = test_datagen.flow_from_directory(
        'dataset/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

classifier.fit_generator(
        train_set,
        steps_per_epoch=8000,
        epochs=25,
        workers = 32,
        use_multiprocessing=True,
        validation_data=test_set,
        validation_steps=2000,
        callbacks=[tensorboard])
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/25
# 8000/8000 [==============================] - 204s 25ms/step - loss: 0.1256 - acc: 0.9521 - val_loss: 1.0645 - val_acc: 0.7585
# Epoch 2/25
# 8000/8000 [==============================] - 205s 26ms/step - loss: 0.0689 - acc: 0.9757 - val_loss: 1.3617 - val_acc: 0.7681
# Epoch 3/25
# 8000/8000 [==============================] - 205s 26ms/step - loss: 0.0479 - acc: 0.9836 - val_loss: 1.5807 - val_acc: 0.7561
# Epoch 4/25
# 8000/8000 [==============================] - 207s 26ms/step - loss: 0.0397 - acc: 0.9871 - val_loss: 1.5512 - val_acc: 0.7716
# Epoch 5/25
# 8000/8000 [==============================] - 207s 26ms/step - loss: 0.0324 - acc: 0.9894 - val_loss: 1.7688 - val_acc: 0.7625
# Epoch 6/25
# 8000/8000 [==============================] - 206s 26ms/step - loss: 0.0275 - acc: 0.9913 - val_loss: 1.8892 - val_acc: 0.7578
# Epoch 7/25
# 8000/8000 [==============================] - 205s 26ms/step - loss: 0.0249 - acc: 0.9919 - val_loss: 1.9096 - val_acc: 0.7686
# Epoch 8/25
# 8000/8000 [==============================] - 206s 26ms/step - loss: 0.0221 - acc: 0.9932 - val_loss: 1.9660 - val_acc: 0.7600
# Epoch 9/25
# 8000/8000 [==============================] - 207s 26ms/step - loss: 0.0195 - acc: 0.9940 - val_loss: 1.9941 - val_acc: 0.7594
# Epoch 10/25
# 6965/8000 [=========================>....] - ETA: 21s - loss: 0.0179 - acc: 0.9945
# Process ForkPoolWorker-19301:
# Process ForkPoolWorker-19321:
# Process ForkPoolWorker-19328:
# Process ForkPoolWorker-19325:
# Process ForkPoolWorker-19306:
# Process ForkPoolWorker-19327:
# Process ForkPoolWorker-19309:
# Process ForkPoolWorker-19326:
# Process ForkPoolWorker-19323:
# Process ForkPoolWorker-19310:
# Process ForkPoolWorker-19316:
# Process ForkPoolWorker-19322:
# Process ForkPoolWorker-19319:
# Process ForkPoolWorker-19324:
# Process ForkPoolWorker-19304:
# Process ForkPoolWorker-19318:
# Process ForkPoolWorker-19311:
# Process ForkPoolWorker-19303:
# Process ForkPoolWorker-19302:
# Process ForkPoolWorker-19315:
# Process ForkPoolWorker-19300:
# Process ForkPoolWorker-19314:
# Process ForkPoolWorker-19299:
# Process ForkPoolWorker-19313:
# Process ForkPoolWorker-19298:
# Process ForkPoolWorker-19312:
# Process ForkPoolWorker-19305:
# Process ForkPoolWorker-19297:
# Process ForkPoolWorker-19308:
# Process ForkPoolWorker-19307:
# Process ForkPoolWorker-19320:
# Process ForkPoolWorker-19317:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-13b2b3c4c47b> in <module>()
#      28         validation_data=test_set,
#      29         validation_steps=2000,
# ---> 30         callbacks=[tensorboard])
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1274                                         use_multiprocessing=use_multiprocessing,
#    1275                                         shuffle=shuffle,
# -> 1276                                         initial_epoch=initial_epoch)
#    1277
#    1278     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2222                     outs = self.train_on_batch(x, y,
#    2223                                                sample_weight=sample_weight,
# -> 2224                                                class_weight=class_weight)
#    2225
#    2226                     if not isinstance(outs, list):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1881             ins = x + y + sample_weights
#    1882         self._make_train_function()
# -> 1883         outputs = self.train_function(ins)
#    1884         if len(outputs) == 1:
#    1885             return outputs[0]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1244, in _get_batches_of_transformed_samples
#     img = img.resize(width_height_tuple, resample)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1244, in _get_batches_of_transformed_samples
#     img = img.resize(width_height_tuple, resample)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1747, in resize
#     self.load()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1747, in resize
#     self.load()
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1244, in _get_batches_of_transformed_samples
#     img = img.resize(width_height_tuple, resample)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1246, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1747, in resize
#     self.load()
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1246, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 696, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in apply_transform
#     cval=cval) for x_channel in x]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 696, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in <listcomp>
#     cval=cval) for x_channel in x]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in apply_transform
#     cval=cval) for x_channel in x]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in <listcomp>
#     cval=cval) for x_channel in x]
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1246, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1244, in _get_batches_of_transformed_samples
#     img = img.resize(width_height_tuple, resample)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 696, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 825, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1747, in resize
#     self.load()
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in apply_transform
#     cval=cval) for x_channel in x]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1246, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 231, in load
#     n, err_code = decoder.decode(b)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 696, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in <listcomp>
#     cval=cval) for x_channel in x]
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in apply_transform
#     cval=cval) for x_channel in x]
# KeyboardInterrupt
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/keras/preprocessing/image.py", line 239, in <listcomp>
#     cval=cval) for x_channel in x]
#   File "/home/bhanuka/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
